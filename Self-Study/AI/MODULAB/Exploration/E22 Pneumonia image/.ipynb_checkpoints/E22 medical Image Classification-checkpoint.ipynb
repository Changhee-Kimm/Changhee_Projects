# %% [markdown]
# ## 폐렴 진단하기
#
# - 데이터셋 : https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia
#
# ```
# $ mkdir -p ~/aiffel/chest_xray
# $ cd ~/Downloads && unzip archive.zip -d ~/aiffel
# ```

# %% [markdown]
# ## 1. set-up

# %%
import re    # 정규표현식 관련된 작업에 필요한 패키지
import os    # I/O 관련된 작업에 필요한 패키지 
import pandas as pd     # 데이터 전처리 관련된 작업에 필요한 패키지
import numpy as np      # 데이터 array 작업에 필요한 패키지
import tensorflow as tf  # 딥러닝 관련된 작업에 필요한 패키지
import matplotlib.pyplot as plt    # 데이터 시각화에 관련된 작업에 필요한 패키지
from sklearn.model_selection import train_test_split  # 데이터 전처리에 필요한 패키지

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE

# 데이터 ROOT 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')

# BATCH_SIZE 변수
BATCH_SIZE = 16

# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# EPOCH 크기 변수
EPOCHS = 5

print(ROOT_PATH)
# Out:
# /home/aiffel/aiffel

# %% [markdown]
# ### 2. 데이터 가져오기

# %%
train_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
test_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/test/*/*'))
val_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*'))

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %% [markdown]
# ### Val 데이터 수가 너무 적어서, Train 모델거를 가져다 써야한다.

# %%
filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*')))

# train, test(val) dataset으로 분할. test_size에 0.2는 20%롤 의미함.
train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %%
train_filenames
# Out:
# ['/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person413_bacteria_1829.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person806_virus_1439.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1582_bacteria_4140.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1102_virus_1822.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1927_bacteria_4836.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person453_virus_936.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1368_virus_2354.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-0460-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person414_bacteria_1835.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person981_bacteria_2908.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person26_bacteria_123.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/IM-0448-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-0520-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person35_bacteria_178.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person70_bacteria_346.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1527_bacteria_3989.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1180_virus_2013.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1661_bacteria_4406.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/IM-0499-0001-0002.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person30_bacteria_150.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-0898-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-0907-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1274_virus_2193.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1843_bacteria_4710.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person471_virus_967.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1835_bacteria_4699.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person692_bacteria_2589.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-1406-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1065_virus_1768.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person375_virus_758.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person525_bacteria_2218.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1211_virus_2056.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person734_virus_1355.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person23_bacteria_87.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/IM-0626-0001-0002.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1486_virus_2580.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person945_bacteria_2870.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1133_virus_1865.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-0390-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person982_bacteria_2909.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1473_virus_2553.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1034_bacteria_2968.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person331_bacteria_1529.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1323_bacteria_3363.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person333_bacteria_1539.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person411_bacteria_1826.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1426_bacteria_3667.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/IM-0437-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1944_bacteria_4869.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person407_bacteria_1822.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/
0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person381_bacteria_1731.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person258_bacteria_1207.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person26_bacteria_124.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-0834-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/IM-0387-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-0637-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person966_bacteria_2891.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-1153-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1617_bacteria_4256.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person564_bacteria_2346.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person470_bacteria_1998.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1310_bacteria_3295.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-1221-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1399_bacteria_3549.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person425_bacteria_1860.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person473_bacteria_2018.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-1214-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person936_bacteria_2861.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person110_virus_205.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-0765-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-1128-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1179_virus_2006.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person356_virus_733.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person370_bacteria_1689.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1530_bacteria_4000.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person308_bacteria_1445.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person422_virus_868.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person55_bacteria_263.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1730_bacteria_4559.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-1319-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-0932-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person950_virus_1621.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1576_bacteria_4127.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-0948-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1261_virus_2148.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/IM-0740-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1343_bacteria_3418.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person929_bacteria_2854.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person315_bacteria_1466.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1069_virus_1772.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-1014-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person940_virus_1609.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-0569-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person140_virus_284.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person518_bacteria_2197.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person266_bacteria_1245.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1405_bacteria_3571.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/IM-0542-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/IM-0417-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/IM-0489-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-0845-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/IM-0721-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person337_bacteria_1562.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-0949-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-1141-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person292_virus_599.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1670_bacteria_4429.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person257_bacteria_1195.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person609_virus_1176.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person519_virus_1038.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-1088-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/IM-0266-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1033_bacteria_2966.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1133_bacteria_3075.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/IM-0497-0001-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/IM-0224-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person398_bacteria_1799.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person51_bacteria_245.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person364_bacteria_1659.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person649_virus_1231.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person506_bacteria_2136.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1177_virus_2002.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person458_virus_945.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-0900-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-0433-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/IM-0460-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1581_virus_2741.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1049_bacteria_2983.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person441_bacteria_1910.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1192_bacteria_3141.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-0406-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person23_bacteria_90.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person992_virus_1670.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1430_bacteria_3697.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1203_bacteria_3155.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person636_virus_1217.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person604_bacteria_2462.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person423_bacteria_1857.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/IM-0117-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-0616-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-0983-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1065_bacteria_2999.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person384_virus_769.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person469_bacteria_1995.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person326_virus_677.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1020_bacteria_2951.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-0611-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person508_bacteria_2142.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person608_bacteria_2473.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person478_bacteria_2032.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person808_bacteria_2716.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person597_bacteria_2451.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1398_virus_2401.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/NORMAL2-IM-1158-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1270_bacteria_3230.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person62_bacteria_301.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person52_bacteria_249.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person889_bacteria_2813.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person815_bacteria_2726.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/IM-0631-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person550_bacteria_2309.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person671_virus_1260.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person16_bacteria_54.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/IM-0491-0001-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/NORMAL/IM-0570-0001.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1109_bacteria_3050.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person417_virus_850.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person545_virus_1081.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person462_virus_951.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person549_bacteria_2306.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1288_bacteria_3251.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person101_virus_188.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person30_bacteria_145.jpeg',
#  '/home/aiffel/aiffel/chest_xray/train/PNEUMONIA/person1519_virus_2646.jpeg',
#  ...]

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print("Normal images count in training set: " + str(COUNT_NORMAL))

COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print("Pneumonia images count in training set: " + str(COUNT_PNEUMONIA))
# Out:
# Normal images count in training set: 1081
# Pneumonia images count in training set: 3104

# %% [markdown]
# ### 정상 vs 폐렴 데이터의 수가 일치하지 않는다. 추후에 조정이 필요하다.

# %% [markdown]
# #### tf.data 인스턴스 생성
# - tf.data는 tensorflow에서 학습시킬 때, 배치처리 작업을 보다 효율적으로 할 수 있도록 함

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
train_list_ds
# Out:
# <TensorSliceDataset shapes: (), types: tf.string>

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Training images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validating images count: " + str(VAL_IMG_COUNT))
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(ROOT_PATH + "/chest_xray/train/*"))])
print(CLASS_NAMES)
# Out:
# ['PNEUMONIA' 'NORMAL']

# %%
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)를 리턴하게 합니다.

# %%
def decode_img(img):
  # 이미지를 uint8 tensor로 바꾼다.
  img = tf.image.decode_jpeg(img, channels=3)
  # img를 범위 [0,1]의 float32 데이터 타입으로 바꾼다.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # img의 이미지 사이즈를 IMAGE_SIZE에서 지정한 사이즈로 수정한다.
  return tf.image.resize(img, IMAGE_SIZE)

def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %% [markdown]
#  - train 데이터 셋과 validation 데이터 셋을 만듭니다. num_parallel_calls 파라미터에서 set-up에서 초기화 한 AUTOTUNE을 이용하면 더욱 빠르게 데이터를 처리해줍니다.

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  True

# %%
test_list_ds = tf.data.Dataset.list_files(str(ROOT_PATH + '/chest_xray/test/*/*'))
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %% [markdown]
#  - 밑에 있는 prepare_for_training() 함수는 학습 데이터를 효율적으로 할 수 있도록 데이터를 변환 시켜줍니다.
#
#
#  - shuffle()을 사용하며 고정 크기 버퍼를 유지하고 해당 버퍼에서 무작위로 균일하게 다음 요소를 선택합니다.
#
#
#  - repeat()를 사용하면 epoch를 진행하면서 여러번 데이터셋을 불러오게 되는데, 이때 repeat()를 사용한 데이터셋의 경우 여러번 데이터셋을 사용할 수 있게 해줍니다.       예를 들어, 100개의 데이터를 10번 반복하면 1000개의 데이터가 필요하게 됩니다. repeat()를 사용하면 자동으로 데이터를 맞춰줍니다.
#
#
#  - batch()를 사용하면 BATCH_SIZE에서 정한 만큼의 배치로 주어집니다.       예를 들어, 100개의 데이터를 10개의 배치로 나누게 되면 각 배치에는 10개의 데이터로 나뉘게 됩니다.
#
#
#  - prefetch()를 사용하면 학습데이터를 나눠서 읽어오기 때문에, 첫 번째 데이터를 GPU에서 학습하는 동안 두 번째 데이터를 CPU에서 준비할 수 있어 리소스의 유휴 상태를 줄일 수 있습니다.

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    ds = ds.repeat()

    ds = ds.batch(BATCH_SIZE)

    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# ### 3. 데이터 시각화

# %%
image_batch, label_batch = next(iter(train_ds))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(16):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# ## 4. CNN 모델링
#  - http://taewan.kim/post/cnn/

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ]
    )
    
    return block

# %%
def dense_block(units, dropout_rate): ##  FC layer
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# ## 5. 데이터 불균형 처리
#  - Normal'과 폐렴에서 'Pneumonia' 중에 'Pneumonia' 데이터가 많이 있었는데, 한 라벨이 너무 많은 경우를 imbalance 하다고 하는데, 데이터를 학습 할 때 imbalance한 데이터의 경우 학습 효과가 좋지 않음
#
#  - 참고 : https://3months.tistory.com/414
#
#  #### Weight Balancing 사용
#  - Loss 계산시, 특정 클래스의 데이터에 더 큰 Loss값을 갖도록 가중치를 부여하는 방법

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 1.94
# Weight for class 1: 0.67

# %% [markdown]
# ## 6. 모델 훈련하기

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %% [markdown]
# 이미지의 라벨이 두 개밖에 없기 때문에 "binary_cross entropy" loss를 사용합니다. optimizer로 'adam'을 사용합니다.
# 성과에 대해서 측정하기 위한 metrics으로 'accuracy', 'precision', 'recall'을 사용합니다.

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/5
# 261/261 [==============================] - 87s 334ms/step - loss: 0.3901 - accuracy: 0.8130 - precision: 0.9467 - recall: 0.7922 - val_loss: 0.7427 - val_accuracy: 0.7423 - val_precision: 0.7423 - val_recall: 1.0000
# Epoch 2/5
# 261/261 [==============================] - 85s 326ms/step - loss: 0.2282 - accuracy: 0.9128 - precision: 0.9708 - recall: 0.9101 - val_loss: 1.5354 - val_accuracy: 0.7433 - val_precision: 0.7433 - val_recall: 1.0000
# Epoch 3/5
# 261/261 [==============================] - 85s 325ms/step - loss: 0.2091 - accuracy: 0.9212 - precision: 0.9739 - recall: 0.9182 - val_loss: 0.2212 - val_accuracy: 0.9077 - val_precision: 0.8897 - val_recall: 1.0000
# Epoch 4/5
# 261/261 [==============================] - 85s 325ms/step - loss: 0.1732 - accuracy: 0.9365 - precision: 0.9787 - recall: 0.9349 - val_loss: 0.1628 - val_accuracy: 0.9375 - val_precision: 0.9876 - val_recall: 0.9276
# Epoch 5/5
# 261/261 [==============================] - 82s 316ms/step - loss: 0.1424 - accuracy: 0.9459 - precision: 0.9819 - recall: 0.9444 - val_loss: 0.4516 - val_accuracy: 0.8673 - val_precision: 0.9969 - val_recall: 0.8243

# %% [markdown]
# ## 7. 결과 확인

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 39/39 [==============================] - 3s 75ms/step - loss: 0.4427 - accuracy: 0.8558 - precision: 0.8695 - recall: 0.9051

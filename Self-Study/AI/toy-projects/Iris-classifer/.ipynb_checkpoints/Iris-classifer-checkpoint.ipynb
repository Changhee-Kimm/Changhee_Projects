# %% [markdown]
# ## Iris Classifier
#
# ### 세가지 품종
#
# ![image.png](attachment:image.png)
#
# 그리고 데이터 셋에 대한 정보

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 데이터 셋을 다루기 전에, 데이터 셋의 정보를 먼저 확인하자!

# %% [markdown]
# 데이터셋을 가져와 보자

# %%
123
저장되나

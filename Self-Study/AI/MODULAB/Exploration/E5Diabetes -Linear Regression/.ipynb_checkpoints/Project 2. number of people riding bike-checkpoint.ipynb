# %% [markdown]
# ### 1. 데이터 가져오기
#
# https://www.kaggle.com/c/bike-sharing-demand/data?select=test.csv

# %%
import os
import pandas as pd
import numpy as np

csv_path=os.getenv("HOME")+"/Desktop/Changhee/changhee_git/Diabetes -Linear Regression/train.csv"
train=pd.read_csv(csv_path,parse_dates=True)
csv_path=os.getenv("HOME")+"/Desktop/Changhee/changhee_git/Diabetes -Linear Regression/test.csv"
test=pd.read_csv(csv_path,parse_dates=True)
# Out:
# (6493, 9)

# %% [markdown]
# ### 2. datetime 컬럼을 datetime 자료형으로 변환하고 연, 월, 일, 시, 분, 초까지 6가지 컬럼 생성하기

# %%
train['year'] = pd.to_datetime(train['datetime']).dt.year
train['month'] = pd.to_datetime(train['datetime']).dt.month
train['day'] = pd.to_datetime(train['datetime']).dt.day
train['hour'] = pd.to_datetime(train['datetime']).dt.hour
train['minute'] = pd.to_datetime(train['datetime']).dt.minute
train['second'] = pd.to_datetime(train['datetime']).dt.second

# %%
test['year'] = pd.to_datetime(test['datetime']).dt.year
test['month'] = pd.to_datetime(test['datetime']).dt.month
test['day'] = pd.to_datetime(test['datetime']).dt.day
test['hour'] = pd.to_datetime(test['datetime']).dt.hour
test['minute'] = pd.to_datetime(test['datetime']).dt.minute
test['second'] = pd.to_datetime(test['datetime']).dt.second
kaggle=test

# %%
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  day  hour  \
# 0        81        0.0       3          13     16  2011      1    1     0
# 1        80        0.0       8          32     40  2011      1    1     1
# 2        80        0.0       5          27     32  2011      1    1     2
# 3        75        0.0       3          10     13  2011      1    1     3
# 4        75        0.0       0           1      1  2011      1    1     4
#
#    minute  second
# 0       0       0
# 1       0       0
# ...

# %%
train.shape
# Out:
# (10886, 18)

# %% [markdown]
# ### 3. year, month, day, hour, minute, second 데이터 개수 시각화하기
#
#  - sns.countplot 활용해서 시각화하기
#
#  - subplot을 활용해서 한 번에 6개의 그래프 함께 시각화하기

# %%
import seaborn as sns
import matplotlib.pylab as plt


plt.subplot(3,2,1)
sns.countplot(train['year'])

plt.subplot(3,2,2)
sns.countplot(train['month'])

plt.subplot(3,2,3)
sns.countplot(train['day'])

plt.subplot(3,2,4)
sns.countplot(train['hour'])

plt.subplot(3,2,5)
sns.countplot(train['minute'])

plt.subplot(3,2,6)
sns.countplot(train['second'])
plt.show()

# %%
year=train['count'].groupby(train['year']).sum()
month=train['count'].groupby(train['month']).sum()
day=train['count'].groupby(train['day']).sum()
hour=train['count'].groupby(train['hour']).sum()


plt.subplot(2,2,1)
year.plot.bar(rot =0)

plt.subplot(2,2,2)
month.plot.bar(rot =0)

plt.subplot(2,2,3)
day.plot.bar(rot =0)

plt.subplot(2,2,4)
hour.plot.bar(rot =0)
plt.show()

# %% [markdown]
# ### 4.  X, y 컬럼 선택 및 train/test 데이터 분리
#
# - X에는 문자열 데이터, 쓸모없는 데이터를 제외한 컬럼의 데이터 넣기
# - count 값을 맞추고자 하므로, y 변수에 count 컬럼의 데이터 넣기

# %%
'''
tips = sns.load_dataset("tips")
tips = pd.get_dummies(tips, columns=['sex', 'smoker', 'day', 'time'])
tips = tips[['total_bill', 'size', 'sex_Male', 'sex_Female', 'smoker_Yes', 'smoker_No',
             'day_Thur', 'day_Fri', 'day_Sat', 'day_Sun', 'time_Lunch', 'time_Dinner', 'tip']]
print("슝=3")
'''
'''
season	holiday	workingday	weather	temp	atemp	
humidity	windspeed	casual	registered	count
'''
# Out:
# '\nseason\tholiday\tworkingday\tweather\ttemp\tatemp\t\nhumidity\twindspeed\tcasual\tregistered\tcount\n'

# %%
trains=train[['season','holiday','workingday','weather','temp','atemp','humidity','windspeed','casual','registered','month'
             ,'hour','count']]

data_pd=pd.DataFrame(trains)
sns.pairplot(data_pd)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(trains.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
X=trains[['season','weather','temp','atemp','humidity','windspeed','month'
             ,'hour' ]]
y=trains[['count']]

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2 , random_state = 45)

# %% [markdown]
# ### 5. LinearRegression 모델 학습
#  - sklearn의 LinearRegression 모델 불러오기 및 학습하기

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### 6.  학습된 모델로 X_test에 대한 예측값 출력 및 손실함수값 계산
# - 학습된 모델에 X_test를 입력해서 예측값 출력하기
# - 모델이 예측한 값과 정답 target 간의 손실함수 값 계산하기
# - mse 값과 함께 rmse 값도 계산하기

# %%
from sklearn.metrics import mean_squared_error


predictions = model.predict(X_test)
predictions
# Out:
# array([[205.34593929],
#        [-11.11037968],
#        [137.00771436],
#        ...,
#        [ 91.2524633 ],
#        [297.21386642],
#        [379.15366641]])

# %%
from sklearn.metrics import mean_squared_error

mse=mean_squared_error(y_test,predictions)
rmse = mse **0.5
print(mse)
print(rmse)
# Out:
# 21889.66946170511
# 147.95157809805582

# %% [markdown]
# ### 7. x축은 temp 또는 humidity로, y축은 count로 예측 결과 시각화하기
#  - x축에 X 데이터 중 temp 데이터를, y축에는 count 데이터를 넣어서 시각화하기
#  - x축에 X 데이터 중 humidity 데이터를, y축에는 count 데이터를 넣어서 시각화하기

# %%
plt.scatter(X_test['humidity'], y_test, label="true")
plt.scatter(X_test['humidity'], predictions, label="pred")
plt.legend()
plt.show()

# %%
plt.scatter(X_test['temp'], y_test, label="true")
plt.scatter(X_test['temp'], predictions, label="pred")
plt.legend()
plt.show()

# %% [markdown]
# ### 결과
#
# file:///home/aiffel/Desktop/Changhee/changhee_git/Diabetes%20-Linear%20Regression/download%20(1).png![image.png](attachment:image.png)
#
# ### 위의 히트맵을 보며 Coefficient 가 0.1 미만인 column은 제거했다.
# ### 처음에 'registered' 와 'casual'은 상관계수가 매우 높아 제거했다.

# %% [markdown]
# ### Kaggle 제출해보기

# %%
test
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-20 00:00:00       1        0           1        1  10.66
# 1     2011-01-20 01:00:00       1        0           1        1  10.66
# 2     2011-01-20 02:00:00       1        0           1        1  10.66
# 3     2011-01-20 03:00:00       1        0           1        1  10.66
# 4     2011-01-20 04:00:00       1        0           1        1  10.66
# ...                   ...     ...      ...         ...      ...    ...
# 6488  2012-12-31 19:00:00       1        0           1        2  10.66
# 6489  2012-12-31 20:00:00       1        0           1        2  10.66
# 6490  2012-12-31 21:00:00       1        0           1        1  10.66
# 6491  2012-12-31 22:00:00       1        0           1        1  10.66
# 6492  2012-12-31 23:00:00       1        0           1        1  10.66
#
#        atemp  humidity  windspeed  year  month  day  hour  minute  second
# ...

# %%
kaggle_X=kaggle[['season','weather','temp','atemp','humidity','windspeed','month'
             ,'hour' ]].values
kaggle_X.shape
# Out:
# (6493, 8)

# %%
predictions = model.predict(kaggle_X)
predictions[predictions < 0] = 0

# %%
kaggle['count'] = predictions
result=kaggle[['datetime','count']]
type(result)
# Out:
# pandas.core.frame.DataFrame

# %%
result.to_csv("Bike_changhee.csv",mode='w',index=False)

# %% [markdown]
# ### 위의 히트맵을 보며 Coefficient 가 0.1 미만인 column은 제거했다.
# ### 처음에 'registered' 와 'casual'은 상관계수가 매우 높아 제거했다.
# ### registered 와 casual을 포함시켰을 때에는 Prediction이 매우 정확했다.
# ###
